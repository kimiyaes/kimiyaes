# %% [markdown]
# <img src="https://tehrandata.org/file/2020/08/%D8%AA%D9%87%D8%B1%D8%A7%D9%86-%D8%AF%DB%8C%D8%AA%D8%A7.png" width=60% />

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Machine Learning in Python</h1>
#     <h3 align="center">Session 02: Pandas</h3>
#     <h4 align="center"><a href="http://www.iran-machinelearning.ir">Soheil Tehranipour</a></h5>
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/450px-Pandas_logo.svg.png">

# %% [markdown]
# <div class="alert alert-block alert-success">
# <p dir="rtl" style="text-align: center;"><span style="font-family: comic sans ms, sans-serif; font-size: 18pt;">آموزش کتابخانه Pandas با بررسی دیتاست Titanic</span></p>
#
# </div>

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">pd.read_csv()</span></strong>
# <p dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier;"><span style="font-size: 18pt;">نحوه خواندن فایل با فرمت csv توسط pandas</span><br /></span></strong></p>
# </div>

# %%
df = pd.read_csv('titanic.csv')

# %%
df2 = pd.read_csv(r'C:\Users\soso\Desktop\data.csv')

# %%
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
# titanic_data = pd.read_csv("titanic.csv")
# for commenting : "Control + /"

# %%
titanic_data = pd.read_csv(r"titanic.csv")

# %%
type(titanic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">head()</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">نمایش ۵ داده اول ذخیره شده در دیتافریم</span></strong></p>
# </div>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em>در صورت ثبت عدد به عنوان پارامتر ورودی، همان تعداد داده از index های ابتدایی دیتافریم را نمایش خواهد داد.</em></span></strong></p>

# %%
titanic_data.head(8)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.00      0      0   19952   26.5500      E12        S    3    NaN
# 6  63.00      1      0   13502   77.9583       D7        S   10    NaN
# 7  39.00      0      0  112050    0.0000      A36        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI

# %%
titanic_data.tail(2)
# Out:
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1307       3         0  Zakarian, Mr. Ortin  male  27.0      0      0    2670
# 1308       3         0   Zimmerman, Mr. Leo  male  29.0      0      0  315082
#
#        fare cabin embarked boat  body home.dest
# 1307  7.225   NaN        C  NaN   NaN       NaN
# 1308  7.875   NaN        S  NaN   NaN       NaN

# %%
titanic_data.sample(3)
# Out:
#      pclass  survived                                               name  \
# 921       3         0                                  Keefe, Mr. Arthur
# 244       1         0                                Ross, Mr. John Hugo
# 85        1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#         sex   age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# 921    male   NaN      0      0    323592   7.2500   NaN        S    A   NaN
# 244    male  36.0      0      0     13049  40.1250   A10        C  NaN   NaN
# 85   female  38.0      1      0  PC 17599  71.2833   C85        C    4   NaN
#
#         home.dest
# 921           NaN
# 244  Winnipeg, MB
# 85   New York, NY

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">shape</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">مشاهده ابعاد (سطر و ستون) دیتافریم<br /></span></strong></p>
# </div>

# %%
titanic_data.shape
# Out:
# (1309, 14)

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">Columns</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">مشاهده عناوین ستون های دیتافریم<br /></span></strong></p>
# </div>

# %%
titanic_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">dtypes</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">مشاهده عناوین ستون ها و تایپ داده هایشان<br /></span></strong></p>
# </div>

# %%
titanic_data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">info()</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">اطلاعات کاملتر در مورد داده ها<br /></span></strong></p>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em><span style="font-size: 12pt;">تعداد کل داده ها</span></em></span></strong></p>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em><span style="font-size: 12pt;">تمامی ستون ها به همراه تایپ داده هایشان</span></em></span></strong></p>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em><span style="font-size: 12pt;">هر ستون چه تعداد داده not-null دارد</span></em></span></strong></p>
# </div>

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><span style="font-family: courier new, courier;"><span style="font-size: 18pt;"><strong>انتخاب سطر و ستون های خاص</strong></span><span style="font-size: 18pt;"><br /></span></span></div>

# %%
titanic_data[['age']]
# Out:
#         age
# 0     29.00
# 1      0.92
# 2      2.00
# 3     30.00
# 4     25.00
# ...     ...
# 1304  14.50
# 1305    NaN
# 1306  26.50
# 1307  27.00
# 1308  29.00
#
# [1309 rows x 1 columns]

# %%
titanic_data['survived']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64

# %%
type(titanic_data['survived'])
# Out:
# pandas.core.series.Series

# %%
type(titanic_data[['survived']])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data[['survived']]
# Out:
#       survived
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0
# ...        ...
# 1304         0
# 1305         0
# 1306         0
# 1307         0
# 1308         0
#
# [1309 rows x 1 columns]

# %%
titanic_data['survived'][5:20:2]
# Out:
# 5     1
# 7     0
# 9     0
# 11    1
# 13    1
# 15    0
# 17    1
# 19    0
# Name: survived, dtype: int64

# %%
titanic_data.survived[0:5]
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: survived, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier;"><span style="font-size: 18pt;">انتخاب ستون ها بر اساس چند عنوان مورد نظر</span><span style="font-size: 18pt;"><br /></span></span></strong></div>

# %%
titanic_data[['survived','age','fare']][:12]
# Out:
#     survived    age      fare
# 0          1  29.00  211.3375
# 1          1   0.92  151.5500
# 2          0   2.00  151.5500
# 3          0  30.00  151.5500
# 4          0  25.00  151.5500
# 5          1  48.00   26.5500
# 6          1  63.00   77.9583
# 7          0  39.00    0.0000
# 8          1  53.00   51.4792
# 9          0  71.00   49.5042
# 10         0  47.00  227.5250
# 11         1  18.00  227.5250

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>value_counts</em>()</span></strong>
# <p dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">پرینت داده های Unique در کل ستون<br /></span></strong></p>
# </div>

# %%
titanic_data['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
titanic_data['survived'].value_counts(normalize=True)* 100
# Out:
# 0    61.802903
# 1    38.197097
# Name: survived, dtype: float64

# %%
titanic_data['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
titanic_data['sex'].value_counts(normalize=True)*100
# Out:
# male      64.400306
# female    35.599694
# Name: sex, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>از بین بازماندگان ۳۳۹ نفر <span style="text-decoration: underline;">زن</span> و تنها ۱۶۱ نفر <span style="text-decoration: underline;">مرد</span> بوده اند.<br /></em></span></strong></div>

# %%
pd.crosstab( titanic_data.pclass,titanic_data.survived  )
# Out:
# survived    0    1
# pclass
# 1         123  200
# 2         158  119
# 3         528  181

# %%
pd.crosstab( titanic_data.sex, titanic_data.survived )
# Out:
# survived    0    1
# sex
# female    127  339
# male      682  161

# %%
pd.crosstab( titanic_data.sex, titanic_data.pclass )
# Out:
# pclass    1    2    3
# sex
# female  144  106  216
# male    179  171  493

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>نرمالایز نمودن داده ها بر اساس سطر<br /></em></span></strong></div>

# %%
pd.crosstab( titanic_data.sex, titanic_data.pclass, normalize = "index" )
# Out:
# pclass         1         2         3
# sex
# female  0.309013  0.227468  0.463519
# male    0.212337  0.202847  0.584816

# %%
pd.crosstab( titanic_data.sex, titanic_data.survived, normalize = "index" )
# Out:
# survived         0         1
# sex
# female    0.272532  0.727468
# male      0.809015  0.190985

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><span style="font-family: comic sans ms, sans-serif; font-size: 18pt;"><strong><em><span style="font-family: courier new, courier;">نرمالایز نمودن داده ها بر اساس ستون</span></em><em><br /></em></strong></span></div>

# %%
pd.crosstab( titanic_data.sex, titanic_data.survived, normalize = "columns" )
# Out:
# survived         0      1
# sex
# female    0.156984  0.678
# male      0.843016  0.322

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>نرمالایز نمودن کل داده ها<br /></em></span></strong></div>

# %%
pd.crosstab( titanic_data.sex, titanic_data.survived, normalize = "all" )
# Out:
# survived         0         1
# sex
# female    0.097021  0.258976
# male      0.521008  0.122995

# %% [markdown]
# <div class="alert alert-block alert-info" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em> لیست کودکان زیر ۵ سال برای ارایه به خانواده بازماندگان</em></span></strong></div>

# %%
below_5_years = titanic_data[ titanic_data.age <= 5 ]

# %%
below_5_years
# Out:
#       pclass  survived                                      name     sex  \
# 1          1         1            Allison, Master. Hudson Trevor    male
# 2          1         0              Allison, Miss. Helen Loraine  female
# 94         1         1                 Dodge, Master. Washington    male
# 339        2         1                 Becker, Master. Richard F    male
# 340        2         1               Becker, Miss. Marion Louise  female
# 359        2         1             Caldwell, Master. Alden Gates    male
# 427        2         1                 Hamalainen, Master. Viljo    male
# 478        2         1                     Laroche, Miss. Louise  female
# 479        2         1  Laroche, Miss. Simonne Marie Anne Andree  female
# 492        2         1                     Mallet, Master. Andre    male
# 514        2         1            Navratil, Master. Edmond Roger    male
# 515        2         1                Navratil, Master. Michel M    male
# 540        2         1                  Quick, Miss. Phyllis May  female
# 548        2         1           Richards, Master. George Sibley    male
# 549        2         1            Richards, Master. William Rowe    male
# 587        2         1               Wells, Master. Ralph Lester    male
# 588        2         1                         Wells, Miss. Joan  female
# 590        2         1                     West, Miss. Barbara J  female
# 591        2         1              West, Miss. Constance Mirium  female
# 611        3         1                 Aks, Master. Philip Frank    male
# 622        3         0   Andersson, Master. Sigvard Harald Elias    male
# 624        3         0         Andersson, Miss. Ellis Anna Maria  female
# 639        3         0               Asplund, Master. Carl Edgar    male
# 641        3         1         Asplund, Master. Edvin Rojj Felix    male
# 643        3         1            Asplund, Miss. Lillian Gertrud  female
# 657        3         1                    Baclini, Miss. Eugenie  female
# 658        3         1             Baclini, Miss. Helene Barbara  female
# 659        3         1            Baclini, Miss. Marie Catherine  female
# 734        3         1    Coutts, Master. William Loch "William"    male
# 747        3         0   Danbom, Master. Gilbert Sigvard Emanuel    male
# 762        3         1                Dean, Master. Bertram Vere    male
# 763        3         1   Dean, Miss. Elizabeth Gladys "Millvina"  female
# 794        3         1             Emanuel, Miss. Virginia Ethel  female
# 826        3         0           Goodwin, Master. Sidney Leonard    male
# 866        3         1                  Hirvonen, Miss. Hildur E  female
# 894        3         1           Johnson, Master. Harold Theodor    male
# 895        3         1              Johnson, Miss. Eleanor Ileen  female
# 916        3         1                        Karun, Miss. Manca  female
# 934        3         1       Kink-Heilmann, Miss. Luise Gretchen  female
# 937        3         0              Klasen, Miss. Gertrud Emilia  female
# 1048       3         1               Nakid, Miss. Maria ("Mary")  female
# 1096       3         0            Palsson, Master. Gosta Leonard    male
# 1098       3         0                Palsson, Miss. Stina Viola  female
# 1101       3         0              Panula, Master. Eino Viljami    male
# 1103       3         0              Panula, Master. Urho Abraham    male
# 1111       3         0            Peacock, Master. Alfred Edward    male
# 1112       3         0                 Peacock, Miss. Treasteall  female
# 1142       3         0                      Rice, Master. Arthur    male
# 1144       3         0                      Rice, Master. Eugene    male
# 1156       3         0               Rosblom, Miss. Salli Helena  female
# 1187       3         1           Sandstrom, Miss. Beatrice Irene  female
# 1189       3         1           Sandstrom, Miss. Marguerite Rut  female
# 1206       3         0                     Skoog, Master. Harald    male
# 1209       3         0             Skoog, Miss. Margit Elizabeth  female
# 1230       3         0                Strom, Miss. Telma Matilda  female
# 1240       3         1           Thomas, Master. Assad Alexander    male
#
#        age  sibsp  parch              ticket      fare    cabin embarked boat  \
# 1     0.92      1      2              113781  151.5500  C22 C26        S   11
# 2     2.00      1      2              113781  151.5500  C22 C26        S  NaN
# 94    4.00      0      2               33638   81.8583      A34        S    5
# 339   1.00      2      1              230136   39.0000       F4        S   11
# 340   4.00      2      1              230136   39.0000       F4        S   11
# 359   0.83      0      2              248738   29.0000      NaN        S   13
# 427   0.67      1      1              250649   14.5000      NaN        S    4
# 478   1.00      1      2       SC/Paris 2123   41.5792      NaN        C   14
# 479   3.00      1      2       SC/Paris 2123   41.5792      NaN        C   14
# 492   1.00      0      2     S.C./PARIS 2079   37.0042      NaN        C   10
# 514   2.00      1      1              230080   26.0000       F2        S    D
# 515   3.00      1      1              230080   26.0000       F2        S    D
# 540   2.00      1      1               26360   26.0000      NaN        S   11
# 548   0.83      1      1               29106   18.7500      NaN        S    4
# 549   3.00      1      1               29106   18.7500      NaN        S    4
# 587   2.00      1      1               29103   23.0000      NaN        S   14
# 588   4.00      1      1               29103   23.0000      NaN        S   14
# 590   0.92      1      2          C.A. 34651   27.7500      NaN        S   10
# 591   5.00      1      2          C.A. 34651   27.7500      NaN        S   10
# 611   0.83      0      1              392091    9.3500      NaN        S   11
# 622   4.00      4      2              347082   31.2750      NaN        S  NaN
# 624   2.00      4      2              347082   31.2750      NaN        S  NaN
# 639   5.00      4      2              347077   31.3875      NaN        S  NaN
# 641   3.00      4      2              347077   31.3875      NaN        S   15
# 643   5.00      4      2              347077   31.3875      NaN        S   15
# 657   0.75      2      1                2666   19.2583      NaN        C    C
# 658   0.75      2      1                2666   19.2583      NaN        C    C
# 659   5.00      2      1                2666   19.2583      NaN        C    C
# 734   3.00      1      1          C.A. 37671   15.9000      NaN        S    2
# 747   0.33      0      2              347080   14.4000      NaN        S  NaN
# 762   1.00      1      2           C.A. 2315   20.5750      NaN        S   10
# 763   0.17      1      2           C.A. 2315   20.5750      NaN        S   10
# 794   5.00      0      0              364516   12.4750      NaN        S   13
# 826   1.00      5      2             CA 2144   46.9000      NaN        S  NaN
# 866   2.00      0      1             3101298   12.2875      NaN        S   15
# 894   4.00      1      1              347742   11.1333      NaN        S   15
# 895   1.00      1      1              347742   11.1333      NaN        S   15
# 916   4.00      0      1              349256   13.4167      NaN        C   15
# 934   4.00      0      2              315153   22.0250      NaN        S    2
# 937   1.00      1      1              350405   12.1833      NaN        S  NaN
# 1048  1.00      0      2                2653   15.7417      NaN        C    C
# 1096  2.00      3      1              349909   21.0750      NaN        S  NaN
# 1098  3.00      3      1              349909   21.0750      NaN        S  NaN
# 1101  1.00      4      1             3101295   39.6875      NaN        S  NaN
# 1103  2.00      4      1             3101295   39.6875      NaN        S  NaN
# 1111  0.75      1      1  SOTON/O.Q. 3101315   13.7750      NaN        S  NaN
# 1112  3.00      1      1  SOTON/O.Q. 3101315   13.7750      NaN        S  NaN
# 1142  4.00      4      1              382652   29.1250      NaN        Q  NaN
# 1144  2.00      4      1              382652   29.1250      NaN        Q  NaN
# 1156  2.00      1      1              370129   20.2125      NaN        S  NaN
# 1187  1.00      1      1             PP 9549   16.7000       G6        S   13
# 1189  4.00      1      1             PP 9549   16.7000       G6        S   13
# 1206  4.00      3      2              347088   27.9000      NaN        S  NaN
# 1209  2.00      3      2              347088   27.9000      NaN        S  NaN
# 1230  2.00      0      1              347054   10.4625       G6        S  NaN
# 1240  0.42      0      1                2625    8.5167      NaN        C   16
#
#       body                             home.dest
# 1      NaN       Montreal, PQ / Chesterville, ON
# 2      NaN       Montreal, PQ / Chesterville, ON
# 94     NaN                     San Francisco, CA
# 339    NaN    Guntur, India / Benton Harbour, MI
# 340    NaN    Guntur, India / Benton Harbour, MI
# 359    NaN     Bangkok, Thailand / Roseville, IL
# 427    NaN                           Detroit, MI
# 478    NaN                         Paris / Haiti
# 479    NaN                         Paris / Haiti
# 492    NaN                  Paris / Montreal, PQ
# 514    NaN                          Nice, France
# 515    NaN                          Nice, France
# 540    NaN         Plymouth, Devon / Detroit, MI
# 548    NaN                  Cornwall / Akron, OH
# 549    NaN                  Cornwall / Akron, OH
# 587    NaN                  Cornwall / Akron, OH
# 588    NaN                  Cornwall / Akron, OH
# 590    NaN                   Bournmouth, England
# 591    NaN                   Bournmouth, England
# 611    NaN           London, England Norfolk, VA
# 622    NaN                   Sweden Winnipeg, MN
# 624    NaN                   Sweden Winnipeg, MN
# 639    NaN                 Sweden  Worcester, MA
# 641    NaN                  Sweden Worcester, MA
# 643    NaN                  Sweden Worcester, MA
# 657    NaN                    Syria New York, NY
# 658    NaN                    Syria New York, NY
# 659    NaN                    Syria New York, NY
# 734    NaN                  England Brooklyn, NY
# 747    NaN                           Stanton, IA
# 762    NaN            Devon, England Wichita, KS
# 763    NaN            Devon, England Wichita, KS
# 794    NaN                          New York, NY
# 826    NaN  Wiltshire, England Niagara Falls, NY
# 866    NaN                                   NaN
# 894    NaN                                   NaN
# 895    NaN                                   NaN
# 916    NaN                                   NaN
# 934    NaN                                   NaN
# 937    NaN                                   NaN
# 1048   NaN                                   NaN
# 1096   4.0                                   NaN
# 1098   NaN                                   NaN
# 1101   NaN                                   NaN
# 1103   NaN                                   NaN
# 1111   NaN                                   NaN
# 1112   NaN                                   NaN
# 1142   NaN                                   NaN
# 1144   NaN                                   NaN
# 1156   NaN                                   NaN
# 1187   NaN                                   NaN
# 1189   NaN                                   NaN
# 1206   NaN                                   NaN
# 1209   NaN                                   NaN
# 1230   NaN                                   NaN
# 1240   NaN                                   NaN

# %%
below_5_years[:10]
# Out:
#      pclass  survived                                      name     sex   age  \
# 1         1         1            Allison, Master. Hudson Trevor    male  0.92
# 2         1         0              Allison, Miss. Helen Loraine  female  2.00
# 94        1         1                 Dodge, Master. Washington    male  4.00
# 339       2         1                 Becker, Master. Richard F    male  1.00
# 340       2         1               Becker, Miss. Marion Louise  female  4.00
# 359       2         1             Caldwell, Master. Alden Gates    male  0.83
# 427       2         1                 Hamalainen, Master. Viljo    male  0.67
# 478       2         1                     Laroche, Miss. Louise  female  1.00
# 479       2         1  Laroche, Miss. Simonne Marie Anne Andree  female  3.00
# 492       2         1                     Mallet, Master. Andre    male  1.00
#
#      sibsp  parch           ticket      fare    cabin embarked boat  body  \
# 1        1      2           113781  151.5500  C22 C26        S   11   NaN
# 2        1      2           113781  151.5500  C22 C26        S  NaN   NaN
# 94       0      2            33638   81.8583      A34        S    5   NaN
# 339      2      1           230136   39.0000       F4        S   11   NaN
# 340      2      1           230136   39.0000       F4        S   11   NaN
# 359      0      2           248738   29.0000      NaN        S   13   NaN
# 427      1      1           250649   14.5000      NaN        S    4   NaN
# 478      1      2    SC/Paris 2123   41.5792      NaN        C   14   NaN
# 479      1      2    SC/Paris 2123   41.5792      NaN        C   14   NaN
# 492      0      2  S.C./PARIS 2079   37.0042      NaN        C   10   NaN
#
#                               home.dest
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 94                    San Francisco, CA
# 339  Guntur, India / Benton Harbour, MI
# 340  Guntur, India / Benton Harbour, MI
# 359   Bangkok, Thailand / Roseville, IL
# 427                         Detroit, MI
# 478                       Paris / Haiti
# 479                       Paris / Haiti
# 492                Paris / Montreal, PQ

# %%
type(below_5_years)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <div class="alert alert-block alert-success" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>چه تعداد از مسافران کودک زیر ۵ سال بودند؟</em></span></strong></div>

# %%
len( below_5_years )
# Out:
# 56

# %%
below_5_years

# %% [markdown]
# <div class="alert alert-block alert-success" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>&nbsp;۳۷ کودک از بین ۵۶ کودک زنده ماندند.<br /></em></span></strong></div>

# %%
below_5_years["survived"].value_counts()
# Out:
# 1    37
# 0    19
# Name: survived, dtype: int64

# %%
titanic_data[ titanic_data.age <= 5 ]["survived"].value_counts(normalize=True)*100
# Out:
# 1    66.071429
# 0    33.928571
# Name: survived, dtype: float64

# %%
below_5_years["sex"].value_counts()
# Out:
# male      28
# female    28
# Name: sex, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>نزدیک به ۲/۳ از کل کودکان زنده ماندند</em></span></strong></div>

# %%
titanic_data[ titanic_data.age <= 5 ]["survived"].value_counts( normalize = True )
# Out:
# 1    0.660714
# 0    0.339286
# Name: survived, dtype: float64

# %%
titanic_data[["survived","age","pclass"]]
# Out:
#       survived    age  pclass
# 0            1  29.00       1
# 1            1   0.92       1
# 2            0   2.00       1
# 3            0  30.00       1
# 4            0  25.00       1
# ...        ...    ...     ...
# 1304         0  14.50       3
# 1305         0    NaN       3
# 1306         0  26.50       3
# 1307         0  27.00       3
# 1308         0  29.00       3
#
# [1309 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-block alert-info" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>از بین مسافرین، افراد با نام Allen را میخواهیم.</em></span></strong></div>

# %%
titanic_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic_data[titanic_data.name.str.contains( "allen",case=False) ]
# Out:
#      pclass  survived                                              name  \
# 0         1         1                     Allen, Miss. Elisabeth Walton
# 342       2         1  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 618       3         0                          Allen, Mr. William Henry
#
#         sex   age  sibsp  parch  ticket      fare cabin embarked boat  body  \
# 0    female  29.0      0      0   24160  211.3375    B5        S    2   NaN
# 342  female  36.0      0      3  230136   39.0000    F4        S   11   NaN
# 618    male  35.0      0      0  373450    8.0500   NaN        S  NaN   NaN
#
#                                              home.dest
# 0                                         St Louis, MO
# 342                 Guntur, India / Benton Harbour, MI
# 618  Lower Clapton, Middlesex or Erdington, Birmingham

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">unique()</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">داده های منحصر به فرد در هر ستون<br /></span></strong></p>
# </div>

# %%
titanic_data.embarked.unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
titanic_data['embarked'].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
titanic_data['age'].unique()
# Out:
# array([29.  ,  0.92,  2.  , 30.  , 25.  , 48.  , 63.  , 39.  , 53.  ,
#        71.  , 47.  , 18.  , 24.  , 26.  , 80.  ,   nan, 50.  , 32.  ,
#        36.  , 37.  , 42.  , 19.  , 35.  , 28.  , 45.  , 40.  , 58.  ,
#        22.  , 41.  , 44.  , 59.  , 60.  , 33.  , 17.  , 11.  , 14.  ,
#        49.  , 76.  , 46.  , 27.  , 64.  , 55.  , 70.  , 38.  , 51.  ,
#        31.  ,  4.  , 54.  , 23.  , 43.  , 52.  , 16.  , 32.5 , 21.  ,
#        15.  , 65.  , 28.5 , 45.5 , 56.  , 13.  , 61.  , 34.  ,  6.  ,
#        57.  , 62.  , 67.  ,  1.  , 12.  , 20.  ,  0.83,  8.  ,  0.67,
#         7.  ,  3.  , 36.5 , 18.5 ,  5.  , 66.  ,  9.  ,  0.75, 70.5 ,
#        22.5 ,  0.33,  0.17, 40.5 , 10.  , 23.5 , 34.5 , 20.5 , 30.5 ,
#        55.5 , 38.5 , 14.5 , 24.5 , 60.5 , 74.  ,  0.42, 11.5 , 26.5 ])

# %%
titanic_data['embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
titanic_data['embarked'].value_counts(dropna = False)
# Out:
# S      914
# C      270
# Q      123
# NaN      2
# Name: embarked, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 14pt;">پرینت اطلاعات مربوط به جنسیت و سن و Pclass کودکان که زنده ماندند.<br /></span></strong></div>

# %%
titanic_data[ (titanic_data.survived == 1) & (titanic_data.age <= 5) ]
# Out:
#       pclass  survived                                      name     sex  \
# 1          1         1            Allison, Master. Hudson Trevor    male
# 94         1         1                 Dodge, Master. Washington    male
# 339        2         1                 Becker, Master. Richard F    male
# 340        2         1               Becker, Miss. Marion Louise  female
# 359        2         1             Caldwell, Master. Alden Gates    male
# 427        2         1                 Hamalainen, Master. Viljo    male
# 478        2         1                     Laroche, Miss. Louise  female
# 479        2         1  Laroche, Miss. Simonne Marie Anne Andree  female
# 492        2         1                     Mallet, Master. Andre    male
# 514        2         1            Navratil, Master. Edmond Roger    male
# 515        2         1                Navratil, Master. Michel M    male
# 540        2         1                  Quick, Miss. Phyllis May  female
# 548        2         1           Richards, Master. George Sibley    male
# 549        2         1            Richards, Master. William Rowe    male
# 587        2         1               Wells, Master. Ralph Lester    male
# 588        2         1                         Wells, Miss. Joan  female
# 590        2         1                     West, Miss. Barbara J  female
# 591        2         1              West, Miss. Constance Mirium  female
# 611        3         1                 Aks, Master. Philip Frank    male
# 641        3         1         Asplund, Master. Edvin Rojj Felix    male
# 643        3         1            Asplund, Miss. Lillian Gertrud  female
# 657        3         1                    Baclini, Miss. Eugenie  female
# 658        3         1             Baclini, Miss. Helene Barbara  female
# 659        3         1            Baclini, Miss. Marie Catherine  female
# 734        3         1    Coutts, Master. William Loch "William"    male
# 762        3         1                Dean, Master. Bertram Vere    male
# 763        3         1   Dean, Miss. Elizabeth Gladys "Millvina"  female
# 794        3         1             Emanuel, Miss. Virginia Ethel  female
# 866        3         1                  Hirvonen, Miss. Hildur E  female
# 894        3         1           Johnson, Master. Harold Theodor    male
# 895        3         1              Johnson, Miss. Eleanor Ileen  female
# 916        3         1                        Karun, Miss. Manca  female
# 934        3         1       Kink-Heilmann, Miss. Luise Gretchen  female
# 1048       3         1               Nakid, Miss. Maria ("Mary")  female
# 1187       3         1           Sandstrom, Miss. Beatrice Irene  female
# 1189       3         1           Sandstrom, Miss. Marguerite Rut  female
# 1240       3         1           Thomas, Master. Assad Alexander    male
#
#        age  sibsp  parch           ticket      fare    cabin embarked boat  \
# 1     0.92      1      2           113781  151.5500  C22 C26        S   11
# 94    4.00      0      2            33638   81.8583      A34        S    5
# 339   1.00      2      1           230136   39.0000       F4        S   11
# 340   4.00      2      1           230136   39.0000       F4        S   11
# 359   0.83      0      2           248738   29.0000      NaN        S   13
# 427   0.67      1      1           250649   14.5000      NaN        S    4
# 478   1.00      1      2    SC/Paris 2123   41.5792      NaN        C   14
# 479   3.00      1      2    SC/Paris 2123   41.5792      NaN        C   14
# 492   1.00      0      2  S.C./PARIS 2079   37.0042      NaN        C   10
# 514   2.00      1      1           230080   26.0000       F2        S    D
# 515   3.00      1      1           230080   26.0000       F2        S    D
# 540   2.00      1      1            26360   26.0000      NaN        S   11
# 548   0.83      1      1            29106   18.7500      NaN        S    4
# 549   3.00      1      1            29106   18.7500      NaN        S    4
# 587   2.00      1      1            29103   23.0000      NaN        S   14
# 588   4.00      1      1            29103   23.0000      NaN        S   14
# 590   0.92      1      2       C.A. 34651   27.7500      NaN        S   10
# 591   5.00      1      2       C.A. 34651   27.7500      NaN        S   10
# 611   0.83      0      1           392091    9.3500      NaN        S   11
# 641   3.00      4      2           347077   31.3875      NaN        S   15
# 643   5.00      4      2           347077   31.3875      NaN        S   15
# 657   0.75      2      1             2666   19.2583      NaN        C    C
# 658   0.75      2      1             2666   19.2583      NaN        C    C
# 659   5.00      2      1             2666   19.2583      NaN        C    C
# 734   3.00      1      1       C.A. 37671   15.9000      NaN        S    2
# 762   1.00      1      2        C.A. 2315   20.5750      NaN        S   10
# 763   0.17      1      2        C.A. 2315   20.5750      NaN        S   10
# 794   5.00      0      0           364516   12.4750      NaN        S   13
# 866   2.00      0      1          3101298   12.2875      NaN        S   15
# 894   4.00      1      1           347742   11.1333      NaN        S   15
# 895   1.00      1      1           347742   11.1333      NaN        S   15
# 916   4.00      0      1           349256   13.4167      NaN        C   15
# 934   4.00      0      2           315153   22.0250      NaN        S    2
# 1048  1.00      0      2             2653   15.7417      NaN        C    C
# 1187  1.00      1      1          PP 9549   16.7000       G6        S   13
# 1189  4.00      1      1          PP 9549   16.7000       G6        S   13
# 1240  0.42      0      1             2625    8.5167      NaN        C   16
#
#       body                           home.dest
# 1      NaN     Montreal, PQ / Chesterville, ON
# 94     NaN                   San Francisco, CA
# 339    NaN  Guntur, India / Benton Harbour, MI
# 340    NaN  Guntur, India / Benton Harbour, MI
# 359    NaN   Bangkok, Thailand / Roseville, IL
# 427    NaN                         Detroit, MI
# 478    NaN                       Paris / Haiti
# 479    NaN                       Paris / Haiti
# 492    NaN                Paris / Montreal, PQ
# 514    NaN                        Nice, France
# 515    NaN                        Nice, France
# 540    NaN       Plymouth, Devon / Detroit, MI
# 548    NaN                Cornwall / Akron, OH
# 549    NaN                Cornwall / Akron, OH
# 587    NaN                Cornwall / Akron, OH
# 588    NaN                Cornwall / Akron, OH
# 590    NaN                 Bournmouth, England
# 591    NaN                 Bournmouth, England
# 611    NaN         London, England Norfolk, VA
# 641    NaN                Sweden Worcester, MA
# 643    NaN                Sweden Worcester, MA
# 657    NaN                  Syria New York, NY
# 658    NaN                  Syria New York, NY
# 659    NaN                  Syria New York, NY
# 734    NaN                England Brooklyn, NY
# 762    NaN          Devon, England Wichita, KS
# 763    NaN          Devon, England Wichita, KS
# 794    NaN                        New York, NY
# 866    NaN                                 NaN
# 894    NaN                                 NaN
# 895    NaN                                 NaN
# 916    NaN                                 NaN
# 934    NaN                                 NaN
# 1048   NaN                                 NaN
# 1187   NaN                                 NaN
# 1189   NaN                                 NaN
# 1240   NaN                                 NaN

# %%
titanic_data[ ( titanic_data.survived == 1 ) & 
              ( titanic_data.age <= 5 ) ][['age','sex','pclass','survived']].sample(5)
# Out:
#        age     sex  pclass  survived
# 1187  1.00  female       3         1
# 895   1.00  female       3         1
# 1240  0.42    male       3         1
# 643   5.00  female       3         1
# 340   4.00  female       2         1

# %% [markdown]
# <div class="alert alert-block alert-success" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 14pt;">پرینت اطلاعات مربوط به جنسیت و Pclass افرادی که زنده ماندند و سن آن ها مشخص نبوده است.<br /></span></strong></div>

# %%
titanic_data[ titanic_data.age.isnull() ][['sex','pclass']]
# Out:
#          sex  pclass
# 15      male       1
# 37      male       1
# 40      male       1
# 46      male       1
# 59    female       1
# ...      ...     ...
# 1293    male       3
# 1297    male       3
# 1302    male       3
# 1303    male       3
# 1305  female       3
#
# [263 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-success" dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 14pt;">پرینت اطلاعات مربوط به جنسیت و Pclass افرادی که زنده ماندند و سن آن ها مشخص  است.<br /></span></strong></div>

# %%
titanic_data[ -titanic_data.age.isnull() ][['sex','pclass']]
# Out:
#          sex  pclass
# 0     female       1
# 1       male       1
# 2     female       1
# 3       male       1
# 4     female       1
# ...      ...     ...
# 1301    male       3
# 1304  female       3
# 1306    male       3
# 1307    male       3
# 1308    male       3
#
# [1046 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-info" dir="rtl" style="text-align: center;"><strong><span style="font-size: 18pt; font-family: courier new, courier;">نحوه ادغام و گروه بندی ستون های مختلف<br /></span></strong></div>

# %%
titanic_data.groupby( 'pclass' )['fare'].mean()
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: fare, dtype: float64

# %%
pclass_age_mean_df = titanic_data.groupby( 'pclass' )['age'].mean().reset_index()
pclass_age_mean_df
# Out:
#    pclass        age
# 0       1  39.159930
# 1       2  29.506705
# 2       3  24.816367

# %%
pclass_gender_age_mean_df = titanic_data.groupby( ['pclass', 'sex'] )['fare'].mean().reset_index()
pclass_gender_age_mean_df
# Out:
#    pclass     sex        fare
# 0       1  female  109.412385
# 1       1    male   69.888385
# 2       2  female   23.234827
# 3       2    male   19.904946
# 4       3  female   15.324250
# 5       3    male   12.415462

# %% [markdown]
# <div class="alert alert-block alert-info" dir="rtl" style="text-align: center;"><strong><span style="font-size: 18pt; font-family: courier new, courier;">نحوه مربت سازی داده های دیتافریم<br /></span></strong></div>

# %%
titanic_data.sort_values( 'age')
# Out:
#       pclass  survived                                     name     sex   age  \
# 763        3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.17
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male  0.33
# 1240       3         1          Thomas, Master. Assad Alexander    male  0.42
# 427        2         1                Hamalainen, Master. Viljo    male  0.67
# 1111       3         0           Peacock, Master. Alfred Edward    male  0.75
# ...      ...       ...                                      ...     ...   ...
# 1293       3         0        Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1297       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
#
#       sibsp  parch              ticket     fare cabin embarked boat  body  \
# 763       1      2           C.A. 2315  20.5750   NaN        S   10   NaN
# 747       0      2              347080  14.4000   NaN        S  NaN   NaN
# 1240      0      1                2625   8.5167   NaN        C   16   NaN
# 427       1      1              250649  14.5000   NaN        S    4   NaN
# 1111      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S  NaN   NaN
# ...     ...    ...                 ...      ...   ...      ...  ...   ...
# 1293      0      0            A/5 2466   8.0500   NaN        S  NaN   NaN
# 1297      0      0          A/4. 34244   7.2500   NaN        S  NaN   NaN
# 1302      0      0                2647   7.2250   NaN        C  NaN   NaN
# 1303      0      0                2627  14.4583   NaN        C  NaN   NaN
# 1305      1      0                2665  14.4542   NaN        C  NaN   NaN
#
#                        home.dest
# 763   Devon, England Wichita, KS
# 747                  Stanton, IA
# 1240                         NaN
# 427                  Detroit, MI
# 1111                         NaN
# ...                          ...
# 1293                         NaN
# 1297                         NaN
# 1302                         NaN
# 1303                         NaN
# 1305                         NaN
#
# [1309 rows x 14 columns]

# %%
titanic_data.sort_values( 'age', ascending = False)
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 135        1         0                          Goldschmidt, Mr. George B
# 9          1         0                            Artagaveytia, Mr. Ramon
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch      ticket     fare cabin embarked boat  \
# 14      male  80.0      0      0       27042  30.0000   A23        S    B
# 61    female  76.0      1      0       19877  78.8500   C46        S    6
# 1235    male  74.0      0      0      347060   7.7750   NaN        S  NaN
# 135     male  71.0      0      0    PC 17754  34.6542    A5        C  NaN
# 9       male  71.0      0      0    PC 17609  49.5042   NaN        C  NaN
# ...      ...   ...    ...    ...         ...      ...   ...      ...  ...
# 1293    male   NaN      0      0    A/5 2466   8.0500   NaN        S  NaN
# 1297    male   NaN      0      0  A/4. 34244   7.2500   NaN        S  NaN
# 1302    male   NaN      0      0        2647   7.2250   NaN        C  NaN
# 1303    male   NaN      0      0        2627  14.4583   NaN        C  NaN
# 1305  female   NaN      1      0        2665  14.4542   NaN        C  NaN
#
#       body                home.dest
# 14     NaN            Hessle, Yorks
# 61     NaN  Little Onn Hall, Staffs
# 1235   NaN                      NaN
# 135    NaN             New York, NY
# 9     22.0      Montevideo, Uruguay
# ...    ...                      ...
# 1293   NaN                      NaN
# 1297   NaN                      NaN
# 1302   NaN                      NaN
# 1303   NaN                      NaN
# 1305   NaN                      NaN
#
# [1309 rows x 14 columns]
